# %%
a = 10
print(a, type(a))
print(a)
# Out:
# 10 <class 'int'>
# 10

# %%
b = 3.14
print(b, type(b))
# Out:
# 3.14 <class 'float'>

# %%
d = "Hello"
print(d, type(d))
# Out:
# Hello <class 'str'>

# %%
e = True
print(e, type(e))
# Out:
# True <class 'bool'>

# %%
c = 2 + 5j
print(c, type(c))
# Out:
# (2+5j) <class 'complex'>

# %%
f = [1, 2, 3, 4]
print(f, type(f))
# Out:
# [1, 2, 3, 4] <class 'list'>

# %%
g = (10, 20, 30)
print(g, type(g))
# Out:
# (10, 20, 30) <class 'tuple'>

# %%
h = {1, 2, 3}
print(h, type(h))
# Out:
# {1, 2, 3} <class 'set'>

# %%
i = {"name": "Gobi", "age": 20}
print(i, type(i))
# Out:
# {'name': 'Gobi', 'age': 20} <class 'dict'>

# %%
a="gobi"
b=(1,2,3,4,5)
print(a, type(a))
print(b,type(b))
# Out:
# gobi <class 'str'>
# (1, 2, 3, 4, 5) <class 'tuple'>

# %%
a = 10
b = 5

print(a + b)   
print(a - b)   
print(a * b)   
print(a / b)   
print(a % b)   
print(a ** b)  
print(a // b)
# Out:
# 15
# 5
# 50
# 2.0
# 0
# 100000
# 2

# %%
a = 10
b = 5

print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# True
# False
# True
# False

# %%
a = True
b = False
print(a and b)
print(a or b)
print(not a)
# Out:
# False
# True
# False

# %%
a = 10
b = a
print(b)
b += a
print(b)
b -= a
print(b)
b *= a
print(b)
b <<= a
print(b)
# Out:
# 10
# 20
# 10
# 100
# 102400
