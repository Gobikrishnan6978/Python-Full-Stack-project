# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\PROJECT CHENNAI\rainfall.csv")

# %%
df.head()
# Out:
#    Name                SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY  \
# 0  ROW1  Andaman & Nicobar Islands  1901  49.2   87.1  29.2    2.3  528.8
# 1  ROW2  Andaman & Nicobar Islands  1902   0.0  159.8  12.2    0.0  446.1
# 2  ROW3  Andaman & Nicobar Islands  1903  12.7  144.0   0.0    1.0  235.1
# 3  ROW4  Andaman & Nicobar Islands  1904   9.4   14.7   0.0  202.4  304.5
# 4  ROW5  Andaman & Nicobar Islands  1905   1.3    0.0   3.3   26.9  279.5
#
#      JUN    JUL  ...    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0  517.5  365.1  ...  388.5  558.2   33.6  3373.2    136.3    560.3
# 1  537.1  228.9  ...  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  479.9  728.4  ...  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  495.1  502.0  ...  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  628.7  368.7  ...  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    June-September  Oct-Dec  Latitude  Longitude
# 0          1696.3    980.3  12.61124   92.83165
# ...

# %%
df.tail()
# Out:
#          Name  SUBDIVISION  YEAR   JAN   FEB   MAR   APR    MAY    JUN    JUL  \
# 4182  ROW4183  Lakshadweep  2012  19.2   0.1   1.6  76.8   21.2  327.0  231.5
# 4183  ROW4184  Lakshadweep  2013  26.2  34.4  37.5   5.3   88.3  426.2  296.4
# 4184  ROW4185  Lakshadweep  2014  53.2  16.1   4.4  14.9   57.4  244.1  116.1
# 4185  ROW4186  Lakshadweep  2015   2.2   0.5   3.7  87.1  133.1  296.6  257.5
# 4186  ROW4187  Lakshadweep  2016  59.6  12.1   3.2   2.6   77.4  321.1  262.6
#
#       ...    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  June-September  \
# 4182  ...  145.9   12.4    8.8  1405.5     19.3     99.6          1119.5
# 4183  ...   72.8   78.1   26.7  1426.3     60.6    131.1          1057.0
# 4184  ...  169.2   59.0   62.3  1395.0     69.3     76.7           958.5
# 4185  ...  165.4  231.0  159.0  1642.9      2.7    223.9           860.9
# 4186  ...   58.6   32.0   74.7  1065.7     71.7     83.2           745.5
#
#       Oct-Dec   Latitude  Longitude
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4187 entries, 0 to 4186
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4187 non-null   object
#  1   SUBDIVISION     4187 non-null   object
#  2   YEAR            4187 non-null   int64
#  3   JAN             4187 non-null   float64
#  4   FEB             4187 non-null   float64
#  5   MAR             4187 non-null   float64
#  6   APR             4187 non-null   float64
#  7   MAY             4187 non-null   float64
#  8   JUN             4187 non-null   float64
#  9   JUL             4187 non-null   float64
#  10  AUG             4187 non-null   float64
#  11  SEP             4187 non-null   float64
#  12  OCT             4187 non-null   float64
#  13  NOV             4187 non-null   float64
#  14  DEC             4187 non-null   float64
#  15  ANNUAL          4187 non-null   float64
#  16  Jan-Feb         4187 non-null   float64
# ...

# %%
df.describe()
# Out:
#               YEAR          JAN          FEB          MAR          APR  \
# count  4187.000000  4187.000000  4187.000000  4187.000000  4187.000000
# mean   1959.206831    18.937772    21.604374    27.395503    43.081712
# std      33.709294    33.780997    35.721764    46.886429    68.123572
# min    1901.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1930.000000     0.600000     0.500000     1.000000     3.000000
# 50%    1959.000000     6.000000     6.500000     7.900000    15.500000
# 75%    1988.000000    22.000000    26.600000    31.300000    49.550000
# max    2017.000000   583.700000   403.500000   605.600000   595.100000
#
#                MAY          JUN          JUL          AUG          SEP  \
# count  4187.000000  4187.000000  4187.000000  4187.000000  4187.000000
# mean     85.646511   230.047704   347.063780   289.762156   197.311863
# std     122.662312   234.136680   268.643091   188.354112   135.466361
# ...

# %%
df.shape
# Out:
# (4187, 22)

# %%
df.columns
# Out:
# Index(['Name', 'SUBDIVISION', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN',
#        'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb',
#        'Mar-May', 'June-September', 'Oct-Dec', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Name               object
# SUBDIVISION        object
# YEAR                int64
# JAN               float64
# FEB               float64
# MAR               float64
# APR               float64
# MAY               float64
# JUN               float64
# JUL               float64
# AUG               float64
# SEP               float64
# OCT               float64
# NOV               float64
# DEC               float64
# ANNUAL            float64
# Jan-Feb           float64
# Mar-May           float64
# June-September    float64
# Oct-Dec           float64
# Latitude          float64
# Longitude         float64
# dtype: object

# %%
df.loc[0]
# Out:
# Name                                   ROW1
# SUBDIVISION       Andaman & Nicobar Islands
# YEAR                                   1901
# JAN                                    49.2
# FEB                                    87.1
# MAR                                    29.2
# APR                                     2.3
# MAY                                   528.8
# JUN                                   517.5
# JUL                                   365.1
# AUG                                   481.1
# SEP                                   332.6
# OCT                                   388.5
# NOV                                   558.2
# DEC                                    33.6
# ANNUAL                               3373.2
# Jan-Feb                               136.3
# Mar-May                               560.3
# June-September                       1696.3
# Oct-Dec                               980.3
# Latitude                           12.61124
# ...

# %%
df.iloc[0]
# Out:
# Name                                   ROW1
# SUBDIVISION       Andaman & Nicobar Islands
# YEAR                                   1901
# JAN                                    49.2
# FEB                                    87.1
# MAR                                    29.2
# APR                                     2.3
# MAY                                   528.8
# JUN                                   517.5
# JUL                                   365.1
# AUG                                   481.1
# SEP                                   332.6
# OCT                                   388.5
# NOV                                   558.2
# DEC                                    33.6
# ANNUAL                               3373.2
# Jan-Feb                               136.3
# Mar-May                               560.3
# June-September                       1696.3
# Oct-Dec                               980.3
# Latitude                           12.61124
# ...

# %%
df.at[0, "Name"]
# Out:
# 'ROW1'

# %%
df.iat[0, 0]
# Out:
# 'ROW1'

# %%
df[df["YEAR"].isin([1915, 2015])]
# Out:
#          Name                SUBDIVISION  YEAR    JAN   FEB   MAR    APR  \
# 13      ROW14  Andaman & Nicobar Islands  1915   45.0  56.7  33.3   40.9
# 109    ROW110  Andaman & Nicobar Islands  2015  126.8   7.6   3.1  138.2
# 208    ROW209          Arunachal Pradesh  2015   30.8  47.5  97.5  287.1
# 225    ROW226          Assam & Meghalaya  1915    9.3  58.9  74.4  201.9
# 325    ROW326          Assam & Meghalaya  2015   13.4  15.5  37.5  250.9
# ...       ...                        ...   ...    ...   ...   ...    ...
# 3952  ROW3953   South Interior Karnataka  2015    1.7   0.2  24.4   80.5
# 3969  ROW3970                     Kerala  1915   16.9  23.5  42.7  106.0
# 4069  ROW4070                     Kerala  2015    3.1   5.8  50.1  214.1
# 4086  ROW4087                Lakshadweep  1915    0.0   0.0  22.9   50.5
# 4185  ROW4186                Lakshadweep  2015    2.2   0.5   3.7   87.1
#
#         MAY    JUN    JUL  ...    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# ...

# %%
df[df["Latitude"].between(20.0,22.06)]
# Out:
#          Name   SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY    JUN  \
# 679    ROW680        Orissa  1901  39.5  65.1  16.1   51.6   79.0   78.2
# 680    ROW681        Orissa  1902   3.4   0.2  14.2  101.1   56.7  108.3
# 681    ROW682        Orissa  1903  19.7  18.9  10.5   34.6   73.3  154.3
# 682    ROW683        Orissa  1904   0.2  12.2  20.6   10.1  100.2  342.9
# 683    ROW684        Orissa  1905  24.3  17.2  66.3   56.9  107.5   92.0
# ...       ...           ...   ...   ...   ...   ...    ...    ...    ...
# 3131  ROW3132  Chhattisgarh  2013   2.8  19.7   4.9   45.8    5.7  263.6
# 3132  ROW3133  Chhattisgarh  2014   2.3  29.0  21.4   17.3   25.0  104.9
# 3133  ROW3134  Chhattisgarh  2015  15.8   1.2  21.2   37.0   13.0  257.6
# 3134  ROW3135  Chhattisgarh  2016   6.1   3.6  24.5    4.4   19.6  164.2
# 3135  ROW3136  Chhattisgarh  2017   0.9   0.7   3.5    0.8   15.6  184.8
#
#         JUL  ...    OCT   NOV   DEC  ANNUAL  Jan-Feb  Mar-May  June-September  \
# ...

# %%
df["Longitude"].where(df["Longitude"] > 85,75 )
# Out:
# 0       92.83165
# 1       92.83165
# 2       92.83165
# 3       92.83165
# 4       92.83165
#           ...
# 4182    75.00000
# 4183    75.00000
# 4184    75.00000
# 4185    75.00000
# 4186    75.00000
# Name: Longitude, Length: 4187, dtype: float64

# %%
df.rename(columns={"YEAR": "year"})
# Out:
#          Name                SUBDIVISION  year   JAN    FEB   MAR    APR  \
# 0        ROW1  Andaman & Nicobar Islands  1901  49.2   87.1  29.2    2.3
# 1        ROW2  Andaman & Nicobar Islands  1902   0.0  159.8  12.2    0.0
# 2        ROW3  Andaman & Nicobar Islands  1903  12.7  144.0   0.0    1.0
# 3        ROW4  Andaman & Nicobar Islands  1904   9.4   14.7   0.0  202.4
# 4        ROW5  Andaman & Nicobar Islands  1905   1.3    0.0   3.3   26.9
# ...       ...                        ...   ...   ...    ...   ...    ...
# 4182  ROW4183                Lakshadweep  2012  19.2    0.1   1.6   76.8
# 4183  ROW4184                Lakshadweep  2013  26.2   34.4  37.5    5.3
# 4184  ROW4185                Lakshadweep  2014  53.2   16.1   4.4   14.9
# 4185  ROW4186                Lakshadweep  2015   2.2    0.5   3.7   87.1
# 4186  ROW4187                Lakshadweep  2016  59.6   12.1   3.2    2.6
#
#         MAY    JUN    JUL  ...    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# ...

# %%
df.assign(Output="weather is arrounded")
# Out:
#          Name                SUBDIVISION  YEAR   JAN    FEB   MAR    APR  \
# 0        ROW1  Andaman & Nicobar Islands  1901  49.2   87.1  29.2    2.3
# 1        ROW2  Andaman & Nicobar Islands  1902   0.0  159.8  12.2    0.0
# 2        ROW3  Andaman & Nicobar Islands  1903  12.7  144.0   0.0    1.0
# 3        ROW4  Andaman & Nicobar Islands  1904   9.4   14.7   0.0  202.4
# 4        ROW5  Andaman & Nicobar Islands  1905   1.3    0.0   3.3   26.9
# ...       ...                        ...   ...   ...    ...   ...    ...
# 4182  ROW4183                Lakshadweep  2012  19.2    0.1   1.6   76.8
# 4183  ROW4184                Lakshadweep  2013  26.2   34.4  37.5    5.3
# 4184  ROW4185                Lakshadweep  2014  53.2   16.1   4.4   14.9
# 4185  ROW4186                Lakshadweep  2015   2.2    0.5   3.7   87.1
# 4186  ROW4187                Lakshadweep  2016  59.6   12.1   3.2    2.6
#
#         MAY    JUN    JUL  ...    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# ...

# %%
df["YEAR"].astype(float)
# Out:
# 0       1901.0
# 1       1902.0
# 2       1903.0
# 3       1904.0
# 4       1905.0
#          ...
# 4182    2012.0
# 4183    2013.0
# 4184    2014.0
# 4185    2015.0
# 4186    2016.0
# Name: YEAR, Length: 2722, dtype: float64
